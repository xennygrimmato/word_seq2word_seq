# %% [markdown]
# <a href="https://colab.research.google.com/github/xennygrimmato/word_seq2word_seq/blob/master/src/train_and_word_by_word_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.33.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.16.2)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.13.1)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.13.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.9)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (0.15.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (3.1)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow) (40.9.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.6/dist-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow) (5.1.3)

# %%
from __future__ import print_function

import os
import json
import pprint
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.layers import Input, LSTM, Dense
import numpy as np
import tensorflow as tf

# %%
if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()
    
  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'fra.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_words = set()
target_words = set()

# File format: <eng-word>\t<french-word>\n
# Get all lines from file
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

input_sequences = []
output_sequences = []
# Go through number of samples you want to train on
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    input_token_list = input_text.split()
    output_token_list = target_text.split()
    input_sequences.append(input_token_list)
    output_sequences.append(output_token_list)
    for word in input_token_list:
        if word not in input_words:
            input_words.add(word)
    for word in output_token_list:
        if word not in target_words:
            target_words.add(word)

print(input_sequences)

input_words = sorted(list(input_words))
target_words = sorted(list(target_words))
num_encoder_tokens = len(input_words)
num_decoder_tokens = len(target_words)
max_encoder_seq_length = max([len(seq) for seq in input_sequences])
max_decoder_seq_length = max([len(seq) for seq in output_sequences])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)


input_token_index = dict(
    [(word, i) for i, word in enumerate(input_words)])
target_token_index = dict(
    [(word, i) for i, word in enumerate(target_words)])

print(input_sequences)
# Out:
# [['Go.'], ['Hi.'], ['Run!'], ['Run!'], ['Who?'], ['Wow!'], ['Fire!'], ['Help!'], ['Jump.'], ['Stop!'], ['Stop!'], ['Stop!'], ['Wait!'], ['Wait!'], ['Go', 'on.'], ['Go', 'on.'], ['Go', 'on.'], ['Hello!'], ['Hello!'], ['I', 'see.'], ['I', 'try.'], ['I', 'won!'], ['I', 'won!'], ['I', 'won.'], ['Oh', 'no!'], ['Attack!'], ['Attack!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Get', 'up.'], ['Go', 'now.'], ['Go', 'now.'], ['Go', 'now.'], ['Got', 'it!'], ['Got', 'it!'], ['Got', 'it?'], ['Got', 'it?'], ['Got', 'it?'], ['Hop', 'in.'], ['Hop', 'in.'], ['Hug', 'me.'], ['Hug', 'me.'], ['I', 'fell.'], ['I', 'fell.'], ['I', 'know.'], ['I', 'left.'], ['I', 'left.'], ['I', 'lost.'], ['I', 'paid.'], ["I'm", '19.'], ["I'm", 'OK.'], ["I'm", 'OK.'], ['Listen.'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['Really?'], ['Really?'], ['Really?'], ['Thanks.'], ['We', 'try.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['Ask', 'Tom.'], ['Awesome!'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'cool.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'kind.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Beat', 'it.'], ['Call', 'me.'], ['Call', 'me.'], ['Call', 'us.'], ['Call', 'us.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'on!'], ['Come', 'on.'], ['Come', 'on.'], ['Come', 'on.'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Get', 'Tom.'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out.'], ['Get', 'out.'], ['Go', 'away!'], ['Go', 'away!'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'slow.'], ['Go', 'slow.'], ['Goodbye!'], ['Hang', 'on!'], ['Hang', 'on!'], ['Hang', 'on.'], ['Hang', 'on.'], ['He', 'quit.'], ['He', 'quit.'], ['He', 'runs.'], ['Help', 'me!'], ['Help', 'me.'], ['Help', 'me.'], ['Help', 'us.'], ['Help', 'us.'], ['Hold', 'it!'], ['Hold', 'on.'], ['Hug', 'Tom.'], ['I', 'agree.'], ['I', 'cried.'], ['I', 'dozed.'], ['I', 'dozed.'], ['I', 'drive.'], ['I', 'smoke.'], ['I', 'snore.'], ['I', 'stink.'], ['I', 'stood.'], ['I', 'stood.'], ['I', 'swore.'], ['I', 'swore.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'waved.'], ["I'll", 'go.'], ["I'm", 'Tom.'], ["I'm", 'fat.'], ["I'm", 'fat.'], ["I'm", 'fit.'], ["I'm", 'hit!'], ["I'm", 'hit!'], ["I'm", 'ill.'], ["I'm", 'sad.'], ["I'm", 'shy.'], ["I'm", 'wet.'], ["I'm", 'wet.'], ["It's", 'me!'], ['Join', 'us.'], ['Join', 'us.'], ['Keep', 'it.'], ['Keep', 'it.'], ['Kiss', 'me.'], ['Kiss', 'me.'], ['Me,', 'too.'], ['Open', 'up.'], ['Open', 'up.'], ['Perfect!'], ['See', 'you.'], ['Show', 'me.'], ['Show', 'me.'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['So', 'long.'], ['Take', 'it.'], ['Take', 'it.'], ['Tell', 'me.'], ['Tell', 'me.'], ['Tom', 'won.'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up.'], ['Wake', 'up.'], ['Wash', 'up.'], ['Wash', 'up.'], ['We', 'know.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['Welcome.'], ['Who', 'won?'], ['Who', 'won?'], ['You', 'run.'], ['Am', 'I', 'fat?'], ['Am', 'I', 'fat?'], ['Ask', 'them.'], ['Ask', 'them.'], ['Back', 'off!'], ['Back', 'off!'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Be', 'a', 'man.'], ['Be', 'a', 'man.'], ['Be', 'still.'], ['Be', 'still.'], ['Be', 'still.'], ['Beats', 'me.'], ['Beats', 'me.'], ['Call', 'Tom.'], ['Call', 'Tom.'], ['Cheer', 'up!'], ['Cool', 'off!'], ['Cuff', 'him.'], ['Drive', 'on.'], ['Drive', 'o ...
# Number of samples: 10000
# Number of unique input tokens: 3107
# Number of unique output tokens: 5803
# Max sequence length for inputs: 5
# Max sequence length for outputs: 10
# [['Go.'], ['Hi.'], ['Run!'], ['Run!'], ['Who?'], ['Wow!'], ['Fire!'], ['Help!'], ['Jump.'], ['Stop!'], ['Stop!'], ['Stop!'], ['Wait!'], ['Wait!'], ['Go', 'on.'], ['Go', 'on.'], ['Go', 'on.'], ['Hello!'], ['Hello!'], ['I', 'see.'], ['I', 'try.'], ['I', 'won!'], ['I', 'won!'], ['I', 'won.'], ['Oh', 'no!'], ['Attack!'], ['Attack!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Get', 'up.'], ['Go', 'now.'], ['Go', 'now.'], ['Go', 'now.'], ['Got', 'it!'], ['Got', 'it!'], ['Got', 'it?'], ['Got', 'it?'], ['Got', 'it?'], ['Hop', 'in.'], ['Hop', 'in.'], ['Hug', 'me.'], ['Hug', 'me.'], ['I', 'fell.'], ['I', 'fell.'], ['I', 'know.'], ['I', 'left.'], ['I', 'left.'], ['I', 'lost.'], ['I', 'paid.'], ["I'm", '19.'], ["I'm", 'OK.'], ["I'm", 'OK.'], ['Listen.'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['Really?'], ['Really?'], ['Really?'], ['Thanks.'], ['We', 'try.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['Ask', 'Tom.'], ['Awesome!'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'cool.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'kind.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Beat', 'it.'], ['Call', 'me.'], ['Call', 'me.'], ['Call', 'us.'], ['Call', 'us.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'on!'], ['Come', 'on.'], ['Come', 'on.'], ['Come', 'on.'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Get', 'Tom.'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out.'], ['Get', 'out.'], ['Go', 'away!'], ['Go', 'away!'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'slow.'], ['Go', 'slow.'], ['Goodbye!'], ['Hang', 'on!'], ['Hang', 'on!'], ['Hang', 'on.'], ['Hang', 'on.'], ['He', 'quit.'], ['He', 'quit.'], ['He', 'runs.'], ['Help', 'me!'], ['Help', 'me.'], ['Help', 'me.'], ['Help', 'us.'], ['Help', 'us.'], ['Hold', 'it!'], ['Hold', 'on.'], ['Hug', 'Tom.'], ['I', 'agree.'], ['I', 'cried.'], ['I', 'dozed.'], ['I', 'dozed.'], ['I', 'drive.'], ['I', 'smoke.'], ['I', 'snore.'], ['I', 'stink.'], ['I', 'stood.'], ['I', 'stood.'], ['I', 'swore.'], ['I', 'swore.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'waved.'], ["I'll", 'go.'], ["I'm", 'Tom.'], ["I'm", 'fat.'], ["I'm", 'fat.'], ["I'm", 'fit.'], ["I'm", 'hit!'], ["I'm", 'hit!'], ["I'm", 'ill.'], ["I'm", 'sad.'], ["I'm", 'shy.'], ["I'm", 'wet.'], ["I'm", 'wet.'], ["It's", 'me!'], ['Join', 'us.'], ['Join', 'us.'], ['Keep', 'it.'], ['Keep', 'it.'], ['Kiss', 'me.'], ['Kiss', 'me.'], ['Me,', 'too.'], ['Open', 'up.'], ['Open', 'up.'], ['Perfect!'], ['See', 'you.'], ['Show', 'me.'], ['Show', 'me.'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['So', 'long.'], ['Take', 'it.'], ['Take', 'it.'], ['Tell', 'me.'], ['Tell', 'me.'], ['Tom', 'won.'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up.'], ['Wake', 'up.'], ['Wash', 'up.'], ['Wash', 'up.'], ['We', 'know.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['Welcome.'], ['Who', 'won?'], ['Who', 'won?'], ['You', 'run.'], ['Am', 'I', 'fat?'], ['Am', 'I', 'fat?'], ['Ask', 'them.'], ['Ask', 'them.'], ['Back', 'off!'], ['Back', 'off!'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Be', 'a', 'man.'], ['Be', 'a', 'man.'], ['Be', 'still.'], ['Be', 'still.'], ['Be', 'still.'], ['Beats', 'me.'], ['Beats', 'me.'], ['Call', 'Tom.'], ['Call', 'Tom.'], ['Cheer', 'up!'], ['Cool', 'off!'], ['Cuff', 'him.'], ['Drive', 'on.'], ['Drive', 'o ...

# %%
# Prepare data to be ingested by the model
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for i, (input_sequence, output_sequence) in enumerate(zip(input_sequences, output_sequences)):
    for t, word in enumerate(input_sequence):
        encoder_input_data[i, t, input_token_index[word]] = 1.
    for t, word in enumerate(output_sequence):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[word]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.
print(input_sequences)
# Out:
# [['Go.'], ['Hi.'], ['Run!'], ['Run!'], ['Who?'], ['Wow!'], ['Fire!'], ['Help!'], ['Jump.'], ['Stop!'], ['Stop!'], ['Stop!'], ['Wait!'], ['Wait!'], ['Go', 'on.'], ['Go', 'on.'], ['Go', 'on.'], ['Hello!'], ['Hello!'], ['I', 'see.'], ['I', 'try.'], ['I', 'won!'], ['I', 'won!'], ['I', 'won.'], ['Oh', 'no!'], ['Attack!'], ['Attack!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Get', 'up.'], ['Go', 'now.'], ['Go', 'now.'], ['Go', 'now.'], ['Got', 'it!'], ['Got', 'it!'], ['Got', 'it?'], ['Got', 'it?'], ['Got', 'it?'], ['Hop', 'in.'], ['Hop', 'in.'], ['Hug', 'me.'], ['Hug', 'me.'], ['I', 'fell.'], ['I', 'fell.'], ['I', 'know.'], ['I', 'left.'], ['I', 'left.'], ['I', 'lost.'], ['I', 'paid.'], ["I'm", '19.'], ["I'm", 'OK.'], ["I'm", 'OK.'], ['Listen.'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['Really?'], ['Really?'], ['Really?'], ['Thanks.'], ['We', 'try.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['Ask', 'Tom.'], ['Awesome!'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'cool.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'kind.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Beat', 'it.'], ['Call', 'me.'], ['Call', 'me.'], ['Call', 'us.'], ['Call', 'us.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'on!'], ['Come', 'on.'], ['Come', 'on.'], ['Come', 'on.'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Get', 'Tom.'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out.'], ['Get', 'out.'], ['Go', 'away!'], ['Go', 'away!'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'slow.'], ['Go', 'slow.'], ['Goodbye!'], ['Hang', 'on!'], ['Hang', 'on!'], ['Hang', 'on.'], ['Hang', 'on.'], ['He', 'quit.'], ['He', 'quit.'], ['He', 'runs.'], ['Help', 'me!'], ['Help', 'me.'], ['Help', 'me.'], ['Help', 'us.'], ['Help', 'us.'], ['Hold', 'it!'], ['Hold', 'on.'], ['Hug', 'Tom.'], ['I', 'agree.'], ['I', 'cried.'], ['I', 'dozed.'], ['I', 'dozed.'], ['I', 'drive.'], ['I', 'smoke.'], ['I', 'snore.'], ['I', 'stink.'], ['I', 'stood.'], ['I', 'stood.'], ['I', 'swore.'], ['I', 'swore.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'waved.'], ["I'll", 'go.'], ["I'm", 'Tom.'], ["I'm", 'fat.'], ["I'm", 'fat.'], ["I'm", 'fit.'], ["I'm", 'hit!'], ["I'm", 'hit!'], ["I'm", 'ill.'], ["I'm", 'sad.'], ["I'm", 'shy.'], ["I'm", 'wet.'], ["I'm", 'wet.'], ["It's", 'me!'], ['Join', 'us.'], ['Join', 'us.'], ['Keep', 'it.'], ['Keep', 'it.'], ['Kiss', 'me.'], ['Kiss', 'me.'], ['Me,', 'too.'], ['Open', 'up.'], ['Open', 'up.'], ['Perfect!'], ['See', 'you.'], ['Show', 'me.'], ['Show', 'me.'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['So', 'long.'], ['Take', 'it.'], ['Take', 'it.'], ['Tell', 'me.'], ['Tell', 'me.'], ['Tom', 'won.'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up.'], ['Wake', 'up.'], ['Wash', 'up.'], ['Wash', 'up.'], ['We', 'know.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['Welcome.'], ['Who', 'won?'], ['Who', 'won?'], ['You', 'run.'], ['Am', 'I', 'fat?'], ['Am', 'I', 'fat?'], ['Ask', 'them.'], ['Ask', 'them.'], ['Back', 'off!'], ['Back', 'off!'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Be', 'a', 'man.'], ['Be', 'a', 'man.'], ['Be', 'still.'], ['Be', 'still.'], ['Be', 'still.'], ['Beats', 'me.'], ['Beats', 'me.'], ['Call', 'Tom.'], ['Call', 'Tom.'], ['Cheer', 'up!'], ['Cool', 'off!'], ['Cuff', 'him.'], ['Drive', 'on.'], ['Drive', 'o ...

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
print(input_sequences)
# Out:
# [['Go.'], ['Hi.'], ['Run!'], ['Run!'], ['Who?'], ['Wow!'], ['Fire!'], ['Help!'], ['Jump.'], ['Stop!'], ['Stop!'], ['Stop!'], ['Wait!'], ['Wait!'], ['Go', 'on.'], ['Go', 'on.'], ['Go', 'on.'], ['Hello!'], ['Hello!'], ['I', 'see.'], ['I', 'try.'], ['I', 'won!'], ['I', 'won!'], ['I', 'won.'], ['Oh', 'no!'], ['Attack!'], ['Attack!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Get', 'up.'], ['Go', 'now.'], ['Go', 'now.'], ['Go', 'now.'], ['Got', 'it!'], ['Got', 'it!'], ['Got', 'it?'], ['Got', 'it?'], ['Got', 'it?'], ['Hop', 'in.'], ['Hop', 'in.'], ['Hug', 'me.'], ['Hug', 'me.'], ['I', 'fell.'], ['I', 'fell.'], ['I', 'know.'], ['I', 'left.'], ['I', 'left.'], ['I', 'lost.'], ['I', 'paid.'], ["I'm", '19.'], ["I'm", 'OK.'], ["I'm", 'OK.'], ['Listen.'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['Really?'], ['Really?'], ['Really?'], ['Thanks.'], ['We', 'try.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['Ask', 'Tom.'], ['Awesome!'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'cool.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'kind.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Beat', 'it.'], ['Call', 'me.'], ['Call', 'me.'], ['Call', 'us.'], ['Call', 'us.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'on!'], ['Come', 'on.'], ['Come', 'on.'], ['Come', 'on.'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Get', 'Tom.'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out.'], ['Get', 'out.'], ['Go', 'away!'], ['Go', 'away!'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'slow.'], ['Go', 'slow.'], ['Goodbye!'], ['Hang', 'on!'], ['Hang', 'on!'], ['Hang', 'on.'], ['Hang', 'on.'], ['He', 'quit.'], ['He', 'quit.'], ['He', 'runs.'], ['Help', 'me!'], ['Help', 'me.'], ['Help', 'me.'], ['Help', 'us.'], ['Help', 'us.'], ['Hold', 'it!'], ['Hold', 'on.'], ['Hug', 'Tom.'], ['I', 'agree.'], ['I', 'cried.'], ['I', 'dozed.'], ['I', 'dozed.'], ['I', 'drive.'], ['I', 'smoke.'], ['I', 'snore.'], ['I', 'stink.'], ['I', 'stood.'], ['I', 'stood.'], ['I', 'swore.'], ['I', 'swore.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'waved.'], ["I'll", 'go.'], ["I'm", 'Tom.'], ["I'm", 'fat.'], ["I'm", 'fat.'], ["I'm", 'fit.'], ["I'm", 'hit!'], ["I'm", 'hit!'], ["I'm", 'ill.'], ["I'm", 'sad.'], ["I'm", 'shy.'], ["I'm", 'wet.'], ["I'm", 'wet.'], ["It's", 'me!'], ['Join', 'us.'], ['Join', 'us.'], ['Keep', 'it.'], ['Keep', 'it.'], ['Kiss', 'me.'], ['Kiss', 'me.'], ['Me,', 'too.'], ['Open', 'up.'], ['Open', 'up.'], ['Perfect!'], ['See', 'you.'], ['Show', 'me.'], ['Show', 'me.'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['So', 'long.'], ['Take', 'it.'], ['Take', 'it.'], ['Tell', 'me.'], ['Tell', 'me.'], ['Tom', 'won.'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up.'], ['Wake', 'up.'], ['Wash', 'up.'], ['Wash', 'up.'], ['We', 'know.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['Welcome.'], ['Who', 'won?'], ['Who', 'won?'], ['You', 'run.'], ['Am', 'I', 'fat?'], ['Am', 'I', 'fat?'], ['Ask', 'them.'], ['Ask', 'them.'], ['Back', 'off!'], ['Back', 'off!'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Be', 'a', 'man.'], ['Be', 'a', 'man.'], ['Be', 'still.'], ['Be', 'still.'], ['Be', 'still.'], ['Beats', 'me.'], ['Beats', 'me.'], ['Call', 'Tom.'], ['Call', 'Tom.'], ['Cheer', 'up!'], ['Cool', 'off!'], ['Cuff', 'him.'], ['Drive', 'on.'], ['Drive', 'o ...

# %%
# Define optimizer, loss
model.compile(optimizer=tf.train.AdamOptimizer(),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# Define chcekpoint path
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, 
                                                 save_weights_only=True,
                                                 verbose=1)

model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=10,
          validation_split=0.2,
          callbacks = [cp_callback])

# Save model
model.save('trained_word_seq_2_word_seq_20percent_validation_split_20_epochs.h5')
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 1.7115 - acc: 0.7612
# Epoch 00001: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 12s 2ms/sample - loss: 1.7102 - acc: 0.7613 - val_loss: 1.8244 - val_acc: 0.7457
# Epoch 2/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 1.4762 - acc: 0.5013
# Epoch 00002: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 1.4754 - acc: 0.5006 - val_loss: 1.7998 - val_acc: 0.4231
# Epoch 3/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 1.3906 - acc: 0.4684
# Epoch 00003: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 1.3902 - acc: 0.4680 - val_loss: 1.7760 - val_acc: 0.3727
# Epoch 4/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 1.3013 - acc: 0.4853
# Epoch 00004: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 1.3003 - acc: 0.4864 - val_loss: 1.7454 - val_acc: 0.5261
# Epoch 5/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 1.1891 - acc: 0.5844
# Epoch 00005: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 1.1896 - acc: 0.5846 - val_loss: 1.7034 - val_acc: 0.5313
# Epoch 6/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 1.0703 - acc: 0.5941
# Epoch 00006: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 1.0702 - acc: 0.5943 - val_loss: 1.6796 - val_acc: 0.5525
# Epoch 7/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 0.9526 - acc: 0.5104
# Epoch 00007: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 0.9527 - acc: 0.5101 - val_loss: 1.6237 - val_acc: 0.3863
# Epoch 8/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 0.8412 - acc: 0.4224
# Epoch 00008: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 0.8405 - acc: 0.4219 - val_loss: 1.6083 - val_acc: 0.3267
# Epoch 9/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 0.7359 - acc: 0.3889
# Epoch 00009: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 0.7356 - acc: 0.3895 - val_loss: 1.6154 - val_acc: 0.3794
# Epoch 10/10
# 7936/8000 [============================>.] - ETA: 0s - loss: 0.6430 - acc: 0.3891
# Epoch 00010: saving model to training_1/cp.ckpt
# 8000/8000 [==============================] - 10s 1ms/sample - loss: 0.6429 - acc: 0.3888 - val_loss: 1.6061 - val_acc: 0.3239
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, word) for word, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, word) for word, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    #target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
print(input_sequences)
for seq_index in range(len(encoder_input_data) - 2, len(encoder_input_data) - 1000, -1):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_sequences[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# [['Go.'], ['Hi.'], ['Run!'], ['Run!'], ['Who?'], ['Wow!'], ['Fire!'], ['Help!'], ['Jump.'], ['Stop!'], ['Stop!'], ['Stop!'], ['Wait!'], ['Wait!'], ['Go', 'on.'], ['Go', 'on.'], ['Go', 'on.'], ['Hello!'], ['Hello!'], ['I', 'see.'], ['I', 'try.'], ['I', 'won!'], ['I', 'won!'], ['I', 'won.'], ['Oh', 'no!'], ['Attack!'], ['Attack!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Cheers!'], ['Get', 'up.'], ['Go', 'now.'], ['Go', 'now.'], ['Go', 'now.'], ['Got', 'it!'], ['Got', 'it!'], ['Got', 'it?'], ['Got', 'it?'], ['Got', 'it?'], ['Hop', 'in.'], ['Hop', 'in.'], ['Hug', 'me.'], ['Hug', 'me.'], ['I', 'fell.'], ['I', 'fell.'], ['I', 'know.'], ['I', 'left.'], ['I', 'left.'], ['I', 'lost.'], ['I', 'paid.'], ["I'm", '19.'], ["I'm", 'OK.'], ["I'm", 'OK.'], ['Listen.'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['No', 'way!'], ['Really?'], ['Really?'], ['Really?'], ['Thanks.'], ['We', 'try.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['We', 'won.'], ['Ask', 'Tom.'], ['Awesome!'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'calm.'], ['Be', 'cool.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'fair.'], ['Be', 'kind.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Be', 'nice.'], ['Beat', 'it.'], ['Call', 'me.'], ['Call', 'me.'], ['Call', 'us.'], ['Call', 'us.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'in.'], ['Come', 'on!'], ['Come', 'on.'], ['Come', 'on.'], ['Come', 'on.'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Drop', 'it!'], ['Get', 'Tom.'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out!'], ['Get', 'out.'], ['Get', 'out.'], ['Go', 'away!'], ['Go', 'away!'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'away.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'home.'], ['Go', 'slow.'], ['Go', 'slow.'], ['Goodbye!'], ['Hang', 'on!'], ['Hang', 'on!'], ['Hang', 'on.'], ['Hang', 'on.'], ['He', 'quit.'], ['He', 'quit.'], ['He', 'runs.'], ['Help', 'me!'], ['Help', 'me.'], ['Help', 'me.'], ['Help', 'us.'], ['Help', 'us.'], ['Hold', 'it!'], ['Hold', 'on.'], ['Hug', 'Tom.'], ['I', 'agree.'], ['I', 'cried.'], ['I', 'dozed.'], ['I', 'dozed.'], ['I', 'drive.'], ['I', 'smoke.'], ['I', 'snore.'], ['I', 'stink.'], ['I', 'stood.'], ['I', 'stood.'], ['I', 'swore.'], ['I', 'swore.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'tried.'], ['I', 'waved.'], ["I'll", 'go.'], ["I'm", 'Tom.'], ["I'm", 'fat.'], ["I'm", 'fat.'], ["I'm", 'fit.'], ["I'm", 'hit!'], ["I'm", 'hit!'], ["I'm", 'ill.'], ["I'm", 'sad.'], ["I'm", 'shy.'], ["I'm", 'wet.'], ["I'm", 'wet.'], ["It's", 'me!'], ['Join', 'us.'], ['Join', 'us.'], ['Keep', 'it.'], ['Keep', 'it.'], ['Kiss', 'me.'], ['Kiss', 'me.'], ['Me,', 'too.'], ['Open', 'up.'], ['Open', 'up.'], ['Perfect!'], ['See', 'you.'], ['Show', 'me.'], ['Show', 'me.'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['Shut', 'up!'], ['So', 'long.'], ['Take', 'it.'], ['Take', 'it.'], ['Tell', 'me.'], ['Tell', 'me.'], ['Tom', 'won.'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up!'], ['Wake', 'up.'], ['Wake', 'up.'], ['Wash', 'up.'], ['Wash', 'up.'], ['We', 'know.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['We', 'lost.'], ['Welcome.'], ['Who', 'won?'], ['Who', 'won?'], ['You', 'run.'], ['Am', 'I', 'fat?'], ['Am', 'I', 'fat?'], ['Ask', 'them.'], ['Ask', 'them.'], ['Back', 'off!'], ['Back', 'off!'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Back', 'off.'], ['Be', 'a', 'man.'], ['Be', 'a', 'man.'], ['Be', 'still.'], ['Be', 'still.'], ['Be', 'still.'], ['Beats', 'me.'], ['Beats', 'me.'], ['Call', 'Tom.'], ['Call', 'Tom.'], ['Cheer', 'up!'], ['Cool', 'off!'], ['Cuff', 'him.'], ['Drive', 'on.'], ['Drive', 'o ...
# -
# Input sentence: ["Don't", 'remind', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'remind', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'play', 'dumb!']
# Decoded sentence: paspas!!!!!
# -
# Input sentence: ["Don't", 'overdo', 'it.']
# Decoded sentence: vaispas!!!!
# -
# Input sentence: ["Don't", 'lose', 'hope.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'lose', 'hope.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'look', 'back.']
# Decoded sentence: lemonde!!!!
# -
# Input sentence: ["Don't", 'look', 'away.']
# Decoded sentence: luilespas.!
# -
# Input sentence: ["Don't", 'lie', 'to', 'us.']
# Decoded sentence: mepaspas.!!
# -
# Input sentence: ["Don't", 'lie', 'to', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'lie', 'to', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'interrupt.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'interrupt.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'interfere.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'interfere.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'get', 'angry.']
# Decoded sentence: mepaspas!!!
# -
# Input sentence: ["Don't", 'freak', 'out.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'forget', 'us.']
# Decoded sentence: nouspas!!!!
# -
# Input sentence: ["Don't", 'forget', 'us.']
# Decoded sentence: nouspas!!!!
# -
# Input sentence: ["Don't", 'follow', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'follow', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'die', 'on', 'me.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'come', 'here.']
# Decoded sentence: pas.pas!!!!
# -
# Input sentence: ["Don't", 'come', 'here.']
# Decoded sentence: pas.pas!!!!
# -
# Input sentence: ["Don't", 'cheat', 'him.']
# Decoded sentence: vaispas!!!!
# -
# Input sentence: ["Don't", 'be', 'stupid.']
# Decoded sentence: soispas!!!!
# -
# Input sentence: ["Don't", 'be', 'so', 'shy.']
# Decoded sentence: soispasun!!
# -
# Input sentence: ["Don't", 'be', 'so', 'shy.']
# Decoded sentence: soispasun!!
# -
# Input sentence: ["Don't", 'be', 'so', 'shy.']
# Decoded sentence: soispasun!!
# -
# Input sentence: ["Don't", 'be', 'scared.']
# Decoded sentence: soispasmoi.
# -
# Input sentence: ["Don't", 'be', 'scared.']
# Decoded sentence: soispasmoi.
# -
# Input sentence: ["Don't", 'be', 'afraid.']
# Decoded sentence: soispasmoi.
# -
# Input sentence: ["Don't", 'be', 'afraid.']
# Decoded sentence: soispasmoi.
# -
# Input sentence: ["Don't", 'be', 'afraid.']
# Decoded sentence: soispasmoi.
# -
# Input sentence: ["Don't", 'be', 'afraid.']
# Decoded sentence: soispasmoi.
# -
# Input sentence: ["Don't", 'back', 'away.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'back', 'away.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'back', 'away.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'back', 'away.']
# Decoded sentence: faispas!!!!
# -
# Input sentence: ["Don't", 'attack', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'attack', 'me.']
# Decoded sentence: mepas.pas.!
# -
# Input sentence: ["Don't", 'apologize.']
# Decoded sentence: essayer.!!!
# -
# Input sentence: ['Does', 'that', 'count?']
# Decoded sentence: ceci???????
# -
# Input sentence: ['Does', 'he', 'like', 'me?']
# Decoded sentence: que????????
# -
# Input sentence: ['Does', 'he', 'know', 'me?']
# Decoded sentence: que????????
# -
# Input sentence: ['Do', 'your', 'own', 'job.']
# Decoded sentence: tontonpois.
# -
# Input sentence: ['Do', 'your', 'own', 'job.']
# Decoded sentence: tontonpois.
# -
# Input sentence: ['Do', 'you', 'want', 'him?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Do', 'you', 'want', 'any?']
# Decoded sentence: ceci???????
# -
# Input sentence: ['Do', 'you', 'trust', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'trust', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'trust', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'trust', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'think', 'so?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'think', 'so?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'think', 'so?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'see', 'them?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'see', 'that?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'remember?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'remember?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'remember?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'remember?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'remember?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'love', 'Tom?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'love', 'Tom?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'like', 'rap?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'know', 'why?']
# Decoded sentence: entrer?????
# -
# Input sentence: ['Do', 'you', 'know', 'why?']
# Decoded sentence: entrer?????
# -
# Input sentence: ['Do', 'you', 'know', 'why?']
# Decoded sentence: entrer?????
# -
# Input sentence: ['Do', 'you', 'know', 'why?']
# Decoded sentence: entrer?????
# -
# Input sentence: ['Do', 'you', 'know', 'him?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Do', 'you', 'know', 'him?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Do', 'you', 'know', 'her?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Do', 'you', 'know', 'her?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Do', 'you', 'know', 'Tom?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'know', 'Tom?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'know', 'CPR?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'know', 'CPR?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'have', 'one?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Do', 'you', 'have', 'one?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Do', 'you', 'go', 'often?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'go', 'often?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'eat', 'meat?']
# Decoded sentence: jusqu'à????
# -
# Input sentence: ['Do', 'you', 'eat', 'meat?']
# Decoded sentence: jusqu'à????
# -
# Input sentence: ['Do', 'you', 'eat', 'fish?']
# Decoded sentence: jusqu'à????
# -
# Input sentence: ['Do', 'you', 'eat', 'fish?']
# Decoded sentence: jusqu'à????
# -
# Input sentence: ['Do', 'you', 'eat', 'fish?']
# Decoded sentence: jusqu'à????
# -
# Input sentence: ['Do', 'you', 'disagree?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'you', 'disagree?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Do', 'what', 'he', 'says.']
# Decoded sentence: quejeje????
# -
# Input sentence: ['Do', 'what', 'he', 'says.']
# Decoded sentence: quejeje????
# -
# Input sentence: ['Do', 'we', 'have', 'time?']
# Decoded sentence: de?????????
# -
# Input sentence: ['Do', 'we', 'have', 'rice?']
# Decoded sentence: queTom?????
# -
# Input sentence: ['Do', 'it', 'right', 'now.']
# Decoded sentence: ça?????????
# -
# Input sentence: ['Do', 'I', 'look', 'tired?']
# Decoded sentence: queje??????
# -
# Input sentence: ['Do', 'I', 'look', 'tired?']
# Decoded sentence: queje??????
# -
# Input sentence: ['Do', 'I', 'have', 'to', 'go?']
# Decoded sentence: quejevous??
# -
# Input sentence: ["Dinner's", 'at', 'six.']
# Decoded sentence: vavite.!!!?
# -
# Input sentence: ['Dinner', 'is', 'ready.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Dig', 'a', 'deep', 'hole.']
# Decoded sentence: chercherundéfaut.
# -
# Input sentence: ['Did', 'you', 'take', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'take', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'say', 'yes?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Did', 'you', 'need', 'me?']
# Decoded sentence: queTom?????
# -
# Input sentence: ['Did', 'you', 'need', 'me?']
# Decoded sentence: queTom?????
# -
# Input sentence: ['Did', 'you', 'miss', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Did', 'you', 'miss', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Did', 'you', 'miss', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Did', 'you', 'like', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'like', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'like', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'like', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'hear', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'hear', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'you', 'drop', 'it?']
# Decoded sentence: vu?????????
# -
# Input sentence: ['Did', 'you', 'drop', 'it?']
# Decoded sentence: vu?????????
# -
# Input sentence: ['Did', 'you', 'drop', 'it?']
# Decoded sentence: vu?????????
# -
# Input sentence: ['Did', 'you', 'drop', 'it?']
# Decoded sentence: vu?????????
# -
# Input sentence: ['Did', 'you', 'drop', 'it?']
# Decoded sentence: vu?????????
# -
# Input sentence: ['Did', 'you', 'drop', 'it?']
# Decoded sentence: vu?????????
# -
# Input sentence: ['Did', 'you', 'do', 'this?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Did', 'you', 'do', 'this?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Did', 'someone', 'die?']
# Decoded sentence: que????????
# -
# Input sentence: ['Did', 'she', 'like', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'she', 'like', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Did', 'he', 'say', 'that?']
# Decoded sentence: que????????
# -
# Input sentence: ['Did', 'he', 'go', 'there?']
# Decoded sentence: est-il?????
# -
# Input sentence: ['Did', 'he', 'go', 'there?']
# Decoded sentence: est-il?????
# -
# Input sentence: ['Did', 'he', 'go', 'there?']
# Decoded sentence: est-il?????
# -
# Input sentence: ['Did', 'he', 'go', 'there?']
# Decoded sentence: est-il?????
# -
# Input sentence: ['Did', 'anyone', 'care?']
# Decoded sentence: quoi???????
# -
# Input sentence: ['Did', 'Tom', 'find', 'it?']
# Decoded sentence: afait??????
# -
# Input sentence: ['Did', 'Tom', 'find', 'it?']
# Decoded sentence: afait??????
# -
# Input sentence: ['Did', 'I', 'miss', 'much?']
# Decoded sentence: ai-jeété???
# -
# Input sentence: ['Did', 'I', 'miss', 'much?']
# Decoded sentence: ai-jeété???
# -
# Input sentence: ['Did', 'I', 'drop', 'that?']
# Decoded sentence: quefait????
# -
# Input sentence: ['Defend', 'yourself.']
# Decoded sentence: ça!maintenant
# -
# Input sentence: ['Defend', 'yourself.']
# Decoded sentence: ça!maintenant
# -
# Input sentence: ['Cut', 'it', 'out,', 'Tom.']
# Decoded sentence: àTom.!!????
# -
# Input sentence: ['Cut', 'it', 'out,', 'Tom.']
# Decoded sentence: àTom.!!????
# -
# Input sentence: ['Crows', 'are', 'black.']
# Decoded sentence: sympa.calme.
# -
# Input sentence: ['Count', 'to', 'thirty.']
# Decoded sentence: peuxnager.faire.
# -
# Input sentence: ['Congratulations!']
# Decoded sentence: vaàTom.!?!?
# -
# Input sentence: ['Congratulations!']
# Decoded sentence: vaàTom.!?!?
# -
# Input sentence: ['Congratulations!']
# Decoded sentence: vaàTom.!?!?
# -
# Input sentence: ['Congratulations!']
# Decoded sentence: vaàTom.!?!?
# -
# Input sentence: ['Congratulations!']
# Decoded sentence: vaàTom.!?!?
# -
# Input sentence: ['Congratulations!']
# Decoded sentence: vaàTom.!?!?
# -
# Input sentence: ['Come', 'on,', 'get', 'up.']
# Decoded sentence: s'ença!????
# -
# Input sentence: ['Come', 'on', 'up', 'here.']
# Decoded sentence: ici.!!!!!!!
# -
# Input sentence: ['Come', 'on', 'up', 'here.']
# Decoded sentence: ici.!!!!!!!
# -
# Input sentence: ['Come', 'in', 'already.']
# Decoded sentence: entrain????
# -
# Input sentence: ['Come', 'in', 'already.']
# Decoded sentence: entrain????
# -
# Input sentence: ['Come', 'if', 'you', 'can.']
# Decoded sentence: vous???????
# -
# Input sentence: ['Come', 'if', 'you', 'can.']
# Decoded sentence: vous???????
# -
# Input sentence: ['Come', 'home', 'early.']
# Decoded sentence: enentrainde
# -
# Input sentence: ['Come', 'downstairs.']
# Decoded sentence: denouveau!?
# -
# Input sentence: ['Come', 'back', 'later.']
# Decoded sentence: àentraindela
# -
# Input sentence: ['Come', 'as', 'you', 'are.']
# Decoded sentence: voustete!??
# -
# Input sentence: ['Come', 'as', 'you', 'are.']
# Decoded sentence: voustete!??
# -
# Input sentence: ['Come', 'and', 'see', 'me.']
# Decoded sentence: deça???????
# -
# Input sentence: ['Come', 'and', 'see', 'me.']
# Decoded sentence: deça???????
# -
# Input sentence: ['Come', 'and', 'get', 'it.']
# Decoded sentence: en?????????
# -
# Input sentence: ['Come', 'and', 'get', 'it.']
# Decoded sentence: en?????????
# -
# Input sentence: ['Come', 'and', 'get', 'it.']
# Decoded sentence: en?????????
# -
# Input sentence: ['Come', 'and', 'get', 'it.']
# Decoded sentence: en?????????
# -
# Input sentence: ['Close', 'your', 'eyes.']
# Decoded sentence: lalacet!chaussure.
# -
# Input sentence: ['Close', 'your', 'eyes.']
# Decoded sentence: lalacet!chaussure.
# -
# Input sentence: ['Close', 'your', 'eyes.']
# Decoded sentence: lalacet!chaussure.
# -
# Input sentence: ['Close', 'the', 'hatch.']
# Decoded sentence: lavoiture!!
# -
# Input sentence: ['Close', 'the', 'hatch.']
# Decoded sentence: lavoiture!!
# -
# Input sentence: ['Close', 'that', 'door.']
# Decoded sentence: laporte!???
# -
# Input sentence: ['Close', 'that', 'door.']
# Decoded sentence: laporte!???
# -
# Input sentence: ['Clean', 'your', 'room.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Clean', 'your', 'room.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Clean', 'your', 'room.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Clean', 'your', 'room.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Check', 'these', 'out.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Check', 'these', 'out.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Check', 'these', 'out.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Check', 'these', 'out.']
# Decoded sentence: ça.!!!!!!!!
# -
# Input sentence: ['Change', 'is', 'scary.']
# Decoded sentence: étaitestetet
# -
# Input sentence: ['Cats', 'like', 'boxes.']
# Decoded sentence: commeaboient.
# -
# Input sentence: ['Cats', 'catch', 'mice.']
# Decoded sentence: chiensaboient.
# -
# Input sentence: ['Cats', 'catch', 'mice.']
# Decoded sentence: chiensaboient.
# -
# Input sentence: ['Catch', 'you', 'later.']
# Decoded sentence: vousl'air??
# -
# Input sentence: ['Can', 'you', 'whistle?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'skip', 'me?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'skip', 'me?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'shut', 'up?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'show', 'me?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'show', 'me?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'see', 'Tom?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'you', 'see', 'Tom?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'you', 'help', 'us?']
# Decoded sentence: peux???????
# -
# Input sentence: ['Can', 'you', 'help', 'us?']
# Decoded sentence: peux???????
# -
# Input sentence: ['Can', 'you', 'help', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'you', 'help', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'you', 'help', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'you', 'help', 'me?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'you', 'hear', 'us?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'hear', 'us?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'hear', 'us?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'hear', 'us?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'hear', 'me?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'do', 'that?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'you', 'do', 'that?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'we', 'prove', 'it?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Can', 'we', 'help', 'you?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'we', 'help', 'you?']
# Decoded sentence: vous???????
# -
# Input sentence: ['Can', 'we', 'fix', 'this?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'we', 'fix', 'this?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'us?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'us?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'us?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'us?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'me?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'me?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'me?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'they', 'see', 'me?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'anyone', 'help?']
# Decoded sentence: marcher!maintenant
# -
# Input sentence: ['Can', 'I', 'pay', 'later?']
# Decoded sentence: queje??????
# -
# Input sentence: ['Can', 'I', 'leave', 'now?']
# Decoded sentence: mejeje?????
# -
# Input sentence: ['Can', 'I', 'keep', 'this?']
# Decoded sentence: que????????
# -
# Input sentence: ['Can', 'I', 'come', 'over?']
# Decoded sentence: entrer?????
# -
# Input sentence: ['Can', 'I', 'come', 'over?']
# Decoded sentence: entrer?????
# -
# Input sentence: ['Can', 'I', 'be', 'honest?']
# Decoded sentence: quejevous??
# -
# Input sentence: ['Can', 'I', 'afford', 'it?']
# Decoded sentence: queje??????
# -
# Input sentence: ['Can', 'I', 'afford', 'it?']
# Decoded sentence: queje??????
# -
# Input sentence: ['Call', 'the', 'police!']
# Decoded sentence: lavoiture!maintenant
# -
# Input sentence: ['Call', 'the', 'police!']
# Decoded sentence: lavoiture!maintenant
# -
# Input sentence: ['Call', 'me', 'anytime.']
# Decoded sentence: àla!!!!!!!!
# -
# Input sentence: ['Bring', 'that', 'here.']
# Decoded sentence: ici.!!!!!!!
# -
# Input sentence: ['Bring', 'that', 'here.']
# Decoded sentence: ici.!!!!!!!
# -
# Input sentence: ['Bring', 'me', 'my', 'hat.']
# Decoded sentence: mamamonmonmon
# -
# Input sentence: ['Bring', 'him', 'to', 'me.']
# Decoded sentence: parler.courir.
# -
# Input sentence: ['Bring', 'him', 'to', 'me.']
# Decoded sentence: parler.courir.
# -
# Input sentence: ['Boys', 'are', 'stupid.']
# Decoded sentence: voici.calme.
# -
# Input sentence: ['Boy', 'was', 'I', 'wrong.']
# Decoded sentence: avezdelaâge.
# -
# Input sentence: ['Boy', 'was', 'I', 'naive.']
# Decoded sentence: étaitl'airtrain
# -
# Input sentence: ['Boy', 'was', 'I', 'naive.']
# Decoded sentence: étaitl'airtrain
# -
# Input sentence: ['Boy', 'was', 'I', 'naive.']
# Decoded sentence: étaitl'airtrain
# -
# Input sentence: ['Boy', 'was', 'I', 'naive.']
# Decoded sentence: étaitl'airtrain
# -
# Input sentence: ['Boil', 'some', 'water.']
# Decoded sentence: disposed'un
# -
# Input sentence: ['Boil', 'some', 'water.']
# Decoded sentence: disposed'un
# -
# Input sentence: ['Black', 'suits', 'you.']
# Decoded sentence: commevousvous
# -
# Input sentence: ['Black', 'suits', 'you.']
# Decoded sentence: commevousvous
# -
# Input sentence: ['Bite', 'the', 'bullet.']
# Decoded sentence: lelaça.!!!!
# -
# Input sentence: ['Bite', 'the', 'bullet.']
# Decoded sentence: lelaça.!!!!
# -
# Input sentence: ['Behave', 'yourself.']
# Decoded sentence: ça!maintenant
# -
# Input sentence: ['Bees', 'make', 'honey.']
# Decoded sentence: lela!!?!?!?
# -
# Input sentence: ['Be', 'very', 'careful.']
# Decoded sentence: calme.ici.!
# -
# Input sentence: ['Be', 'very', 'careful.']
# Decoded sentence: calme.ici.!
# -
# Input sentence: ['Be', 'very', 'careful.']
# Decoded sentence: calme.ici.!
# -
# Input sentence: ['Be', 'very', 'careful.']
# Decoded sentence: calme.ici.!
# -
# Input sentence: ['Be', 'very', 'careful.']
# Decoded sentence: calme.ici.!
# -
# Input sentence: ['Be', 'very', 'careful.']
# Decoded sentence: calme.ici.!
# -
# Input sentence: ['Be', 'quiet,', 'girls.']
# Decoded sentence: !!!!!!!!!!!
# -
# Input sentence: ['Be', 'more', 'precise.']
# Decoded sentence: tranquille!
# -
# Input sentence: ['Be', 'more', 'precise.']
# Decoded sentence: tranquille!
# -
# Input sentence: ['Be', 'careful,', 'Tom.']
# Decoded sentence: Tom.!!!!!!!
# -
# Input sentence: ['Be', 'careful,', 'Tom.']
# Decoded sentence: Tom.!!!!!!!
# -
# Input sentence: ['Be', 'careful,', 'Tom!']
# Decoded sentence: prudent!!!!
# -
# Input sentence: ['Balls', 'are', 'round.']
# Decoded sentence: voilà!!!!!!
# -
# Input sentence: ['Ask', 'me', 'tomorrow.']
# Decoded sentence: à!!!!!!!!!!
# -
# Input sentence: ['Ask', 'me', 'tomorrow.']
# Decoded sentence: à!!!!!!!!!!
# -
# Input sentence: ['Ask', 'me', 'anything!']
# Decoded sentence: àmoi.!!!!!!
# -
# Input sentence: ["Aren't", 'you', 'late?']
# Decoded sentence: ànous.?????
# -
# Input sentence: ["Aren't", 'you', 'late?']
# Decoded sentence: ànous.?????
# -
# Input sentence: ["Aren't", 'you', 'cold?']
# Decoded sentence: ànous.?????
# -
# Input sentence: ["Aren't", 'we', 'lucky?']
# Decoded sentence: ànous.?????
# -
# Input sentence: ["Aren't", 'we', 'lucky?']
# Decoded sentence: ànous.?????
# -
# Input sentence: ["Aren't", 'we', 'lucky?']
# Decoded sentence: ànous.?????
# -
# Input sentence: ['Are', 'you', 'working?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'working?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'working?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'winning?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'winning?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'winning?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'unlucky?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'unlucky?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'unlucky?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'unlucky?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'unlucky?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'thirsty?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'thirsty?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'thirsty?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'thirsty?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'sisters?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'sincere?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'sincere?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'serious?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'serious?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'serious?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'serious?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'you', 'relaxed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'relaxed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'relaxed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'relaxed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'relaxed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'relaxed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'on', 'dope?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'on', 'dope?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'on', 'dope?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'on', 'dope?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'on', 'dope?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'on', 'dope?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'nervous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'nervous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'nervous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'married?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'looking?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'you', 'looking?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'you', 'kidding?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'kidding?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'kidding?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'kidding?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'kidding?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'kidding?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'jealous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'jealous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'jealous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'jealous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'jealous?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'insured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'insured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'injured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'injured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'injured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'injured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'injured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'injured?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'healthy?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'guys', 'OK?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'excited?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'excited?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'excited?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'excited?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'envious?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'dressed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'dressed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'dressed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'dressed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'dressed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'dressed?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'doctors?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'certain?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'certain?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'certain?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'certain?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'certain?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'at', 'work?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'at', 'work?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'at', 'home?']
# Decoded sentence: chez???????
# -
# Input sentence: ['Are', 'you', 'all', 'set?']
# Decoded sentence: sûr????????
# -
# Input sentence: ['Are', 'you', 'a', 'model?']
# Decoded sentence: un?????????
# -
# Input sentence: ['Are', 'you', 'a', 'ghost?']
# Decoded sentence: un?????????
# -
# Input sentence: ['Are', 'you', 'a', 'ghost?']
# Decoded sentence: un?????????
# -
# Input sentence: ['Are', 'you', 'a', 'ghost?']
# Decoded sentence: un?????????
# -
# Input sentence: ['Are', 'you', 'Chinese?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'Chinese?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'you', 'Chinese?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Are', 'we', 'prepared?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'we', 'prepared?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'we', 'prepared?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'we', 'prepared?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'we', 'finished?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'we', 'all', 'here?']
# Decoded sentence: y??????????
# -
# Input sentence: ['Are', 'we', 'all', 'here?']
# Decoded sentence: y??????????
# -
# Input sentence: ['Are', 'those', 'yours?']
# Decoded sentence: lamaison???
# -
# Input sentence: ['Are', 'those', 'yours?']
# Decoded sentence: lamaison???
# -
# Input sentence: ['Are', 'those', 'yours?']
# Decoded sentence: lamaison???
# -
# Input sentence: ['Are', 'these', 'yours?']
# Decoded sentence: àla????????
# -
# Input sentence: ['Are', 'ghosts', 'real?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Are', 'drinks', 'free?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Are', 'drinks', 'free?']
# Decoded sentence: occupé?????
# -
# Input sentence: ['Anybody', 'will', 'do.']
# Decoded sentence: surviendra.
# -
# Input sentence: ['Anybody', 'see', 'you?']
# Decoded sentence: t'a????????
# -
# Input sentence: ['Anybody', 'in', 'here?']
# Decoded sentence: a-t-ilquelqu'un
# -
# Input sentence: ['Am', 'I', 'understood?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Am', 'I', 'reinstated?']
# Decoded sentence: en?????????
# -
# Input sentence: ['Am', 'I', 'boring', 'you?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Am', 'I', 'boring', 'you?']
# Decoded sentence: ???????????
# -
# Input sentence: ['Am', 'I', 'alone', 'here?']
# Decoded sentence: entrain????
# -
# Input sentence: ['All', 'are', 'present.']
# Decoded sentence: sontlà.train
# -
# Input sentence: ['All', 'are', 'present.']
# Decoded sentence: sontlà.train
# -
# Input sentence: ["Ain't", 'that', 'cute?']
# Decoded sentence: àvoir??????
# -
# Input sentence: ['Adjust', 'your', 'tie.']
# Decoded sentence: tonton!!!!!
# -
# Input sentence: ['Adjust', 'your', 'tie.']
# Decoded sentence: tonton!!!!!
# -
# Input sentence: ['About', 'what', 'time?']
# Decoded sentence: adeTom.Tom.
# -
# Input sentence: ['A', 'man', 'must', 'work.']
# Decoded sentence: chiensmarcher.
# -
# Input sentence: ['A', 'fish', 'can', 'swim.']
# Decoded sentence: chienspeuvent
# -
# Input sentence: ['A', 'boat', 'capsized.']
# Decoded sentence: commenon.Tom.
# -
# Input sentence: ['A', 'boat', 'capsized.']
# Decoded sentence: commenon.Tom.
# -
# Input sentence: ['Your', 'wife', 'left.']
# Decoded sentence: dudusiens.!
# -
# Input sentence: ["You've", 'done', 'it!']
# Decoded sentence: avezl'airTom.
# -
# Input sentence: ["You've", 'done', 'it!']
# Decoded sentence: avezl'airTom.
# -
# Input sentence: ["You're", 'winning.']
# Decoded sentence: juste.depremier.
# -
# Input sentence: ["You're", 'winning.']
# Decoded sentence: juste.depremier.
# -
# Input sentence: ["You're", 'winning.']
# Decoded sentence: juste.depremier.
# -
# Input sentence: ["You're", 'winning.']
# Decoded sentence: juste.depremier.
# -
# Input sentence: ["You're", 'welcome.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'welcome.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'welcome.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'welcome.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'useless.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'through.']
# Decoded sentence: asdeTom.!mentir.
# -
# Input sentence: ["You're", 'through.']
# Decoded sentence: asdeTom.!mentir.
# -
# Input sentence: ["You're", 'through.']
# Decoded sentence: asdeTom.!mentir.
# -
# Input sentence: ["You're", 'the', 'pro.']
# Decoded sentence: ladeschef.de
# -
# Input sentence: ["You're", 'the', 'pro.']
# Decoded sentence: ladeschef.de
# -
# Input sentence: ["You're", 'so', 'mean.']
# Decoded sentence: suistellement
# -
# Input sentence: ["You're", 'so', 'mean.']
# Decoded sentence: suistellement
# -
# Input sentence: ["You're", 'so', 'mean.']
# Decoded sentence: suistellement
# -
# Input sentence: ["You're", 'so', 'mean.']
# Decoded sentence: suistellement
# -
# Input sentence: ["You're", 'so', 'mean.']
# Decoded sentence: suistellement
# -
# Input sentence: ["You're", 'so', 'mean.']
# Decoded sentence: suistellement
# -
# Input sentence: ["You're", 'smashed.']
# Decoded sentence: êtessournois.
# -
# Input sentence: ["You're", 'sloshed.']
# Decoded sentence: êtessournois.
# -
# Input sentence: ["You're", 'selfish.']
# Decoded sentence: êtesmatinal.
# -
# Input sentence: ["You're", 'selfish.']
# Decoded sentence: êtesmatinal.
# -
# Input sentence: ["You're", 'selfish.']
# Decoded sentence: êtesmatinal.
# -
# Input sentence: ["You're", 'psychic.']
# Decoded sentence: êtesavide.!
# -
# Input sentence: ["You're", 'psychic.']
# Decoded sentence: êtesavide.!
# -
# Input sentence: ["You're", 'psyched.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'psyched.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'precise.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'precise.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'precise.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'not', 'fit.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fit.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fit.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fit.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fat.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fat.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fat.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fat.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'fat.']
# Decoded sentence: nepasdrôle.
# -
# Input sentence: ["You're", 'not', 'bad.']
# Decoded sentence: nepaspas.pas.
# -
# Input sentence: ["You're", 'not', 'bad.']
# Decoded sentence: nepaspas.pas.
# -
# Input sentence: ["You're", 'no', 'help.']
# Decoded sentence: n'aipasdrôle.
# -
# Input sentence: ["You're", 'no', 'help.']
# Decoded sentence: n'aipasdrôle.
# -
# Input sentence: ["You're", 'my', 'type.']
# Decoded sentence: mangemachien.
# -
# Input sentence: ["You're", 'my', 'boss.']
# Decoded sentence: mamamamama!
# -
# Input sentence: ["You're", 'my', 'boss.']
# Decoded sentence: mamamamama!
# -
# Input sentence: ["You're", 'my', 'boss.']
# Decoded sentence: mamamamama!
# -
# Input sentence: ["You're", 'my', 'boss.']
# Decoded sentence: mamamamama!
# -
# Input sentence: ["You're", 'kidding!']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'kidding!']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'kidding!']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'kidding!']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'jealous.']
# Decoded sentence: êtessournois.
# -
# Input sentence: ["You're", 'invited.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ["You're", 'invited.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ["You're", 'invited.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ["You're", 'invited.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ["You're", 'invited.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ["You're", 'invited.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ["You're", 'in', 'luck.']
# Decoded sentence: esbonne.avance.
# -
# Input sentence: ["You're", 'in', 'luck.']
# Decoded sentence: esbonne.avance.
# -
# Input sentence: ["You're", 'in', 'luck.']
# Decoded sentence: esbonne.avance.
# -
# Input sentence: ["You're", 'in', 'luck.']
# Decoded sentence: esbonne.avance.
# -
# Input sentence: ["You're", 'in', 'luck.']
# Decoded sentence: esbonne.avance.
# -
# Input sentence: ["You're", 'in', 'luck.']
# Decoded sentence: esbonne.avance.
# -
# Input sentence: ["You're", 'in', 'love.']
# Decoded sentence: esenavance.
# -
# Input sentence: ["You're", 'in', 'love.']
# Decoded sentence: esenavance.
# -
# Input sentence: ["You're", 'in', 'love.']
# Decoded sentence: esenavance.
# -
# Input sentence: ["You're", 'in', 'love.']
# Decoded sentence: esenavance.
# -
# Input sentence: ["You're", 'in', 'love.']
# Decoded sentence: esenavance.
# -
# Input sentence: ["You're", 'foolish.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'foolish.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'foolish.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'foolish.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'foolish.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'foolish.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'finicky.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'finicky.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'finicky.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'finicky.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'finicky.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'finicky.']
# Decoded sentence: êtesavide.avance.
# -
# Input sentence: ["You're", 'elusive.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'elusive.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'correct.']
# Decoded sentence: semblezoccupé.
# -
# Input sentence: ["You're", 'careful.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'careful.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'callous.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'callous.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'awesome.']
# Decoded sentence: esdur.dur.dur.
# -
# Input sentence: ["You're", 'awesome.']
# Decoded sentence: esdur.dur.dur.
# -
# Input sentence: ["You're", 'awesome.']
# Decoded sentence: esdur.dur.dur.
# -
# Input sentence: ["You're", 'awesome.']
# Decoded sentence: esdur.dur.dur.
# -
# Input sentence: ["You're", 'amusing.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'amusing.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'amazing.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'amazing.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'amazing.']
# Decoded sentence: êtesbonne.avance.
# -
# Input sentence: ["You're", 'all', 'set.']
# Decoded sentence: êtesoccupé.
# -
# Input sentence: ["You're", 'all', 'set.']
# Decoded sentence: êtesoccupé.
# -
# Input sentence: ["You're", 'all', 'mad.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'all', 'mad.']
# Decoded sentence: êtesgrande.
# -
# Input sentence: ["You're", 'a', 'thief.']
# Decoded sentence: ununmenteur.
# -
# Input sentence: ["You're", 'a', 'thief.']
# Decoded sentence: ununmenteur.
# -
# Input sentence: ["You're", 'a', 'thief.']
# Decoded sentence: ununmenteur.
# -
# Input sentence: ["You're", 'a', 'thief.']
# Decoded sentence: ununmenteur.
# -
# Input sentence: ["You're", 'a', 'prude.']
# Decoded sentence: êtesuncélébrité.
# -
# Input sentence: ["You're", 'a', 'prude.']
# Decoded sentence: êtesuncélébrité.
# -
# Input sentence: ["You're", 'a', 'prude.']
# Decoded sentence: êtesuncélébrité.
# -
# Input sentence: ["You're", 'a', 'prude.']
# Decoded sentence: êtesuncélébrité.
# -
# Input sentence: ["You're", 'a', 'child.']
# Decoded sentence: ununcélébrité.
# -
# Input sentence: ["You're", 'a', 'child.']
# Decoded sentence: ununcélébrité.
# -
# Input sentence: ["You're", 'a', 'child.']
# Decoded sentence: ununcélébrité.
# -
# Input sentence: ["You're", 'a', 'child.']
# Decoded sentence: ununcélébrité.
# -
# Input sentence: ["You'll", 'be', 'safe.']
# Decoded sentence: voilà!!!!!!
# -
# Input sentence: ["You'll", 'be', 'fine.']
# Decoded sentence: gentil!!!!!
# -
# Input sentence: ["You'll", 'be', 'fine.']
# Decoded sentence: gentil!!!!!
# -
# Input sentence: ["You'll", 'all', 'die.']
# Decoded sentence: grandiront.
# -
# Input sentence: ["You'd", 'like', 'Tom.']
# Decoded sentence: Tom.ça.Tom.
# -
# Input sentence: ["You'd", 'like', 'Tom.']
# Decoded sentence: Tom.ça.Tom.
# -
# Input sentence: ['You', 'write', 'well.']
# Decoded sentence: teTom.!!!!!
# -
# Input sentence: ['You', 'write', 'well.']
# Decoded sentence: teTom.!!!!!
# -
# Input sentence: ['You', 'were', 'happy.']
# Decoded sentence: étionsseul.
# -
# Input sentence: ['You', 'were', 'happy.']
# Decoded sentence: étionsseul.
# -
# Input sentence: ['You', 'were', 'happy.']
# Decoded sentence: étionsseul.
# -
# Input sentence: ['You', 'were', 'happy.']
# Decoded sentence: étionsseul.
# -
# Input sentence: ['You', 'were', 'great.']
# Decoded sentence: étaisperdu.
# -
# Input sentence: ['You', 'were', 'great.']
# Decoded sentence: étaisperdu.
# -
# Input sentence: ['You', 'stay', 'there.']
# Decoded sentence: chiensseul.
# -
# Input sentence: ['You', 'smell', 'good.']
# Decoded sentence: perdu.denager.
# -
# Input sentence: ['You', 'smashed', 'it.']
# Decoded sentence: lele!!!!!!!
# -
# Input sentence: ['You', 'smashed', 'it.']
# Decoded sentence: lele!!!!!!!
# -
# Input sentence: ['You', 'should', 'eat.']
# Decoded sentence: devraisessayer.
# -
# Input sentence: ['You', 'should', 'eat.']
# Decoded sentence: devraisessayer.
# -
# Input sentence: ['You', 'seem', 'upset.']
# Decoded sentence: semblezdechef.
# -
# Input sentence: ['You', 'seem', 'upset.']
# Decoded sentence: semblezdechef.
# -
# Input sentence: ['You', 'seem', 'upset.']
# Decoded sentence: semblezdechef.
# -
# Input sentence: ['You', 'seem', 'upset.']
# Decoded sentence: semblezdechef.
# -
# Input sentence: ['You', 'seem', 'upset.']
# Decoded sentence: semblezdechef.
# -
# Input sentence: ['You', 'seem', 'upset.']
# Decoded sentence: semblezdechef.
# -
# Input sentence: ['You', 'seem', 'happy.']
# Decoded sentence: semblezici.
# -
# Input sentence: ['You', 'seem', 'happy.']
# Decoded sentence: semblezici.
# -
# Input sentence: ['You', 'seem', 'happy.']
# Decoded sentence: semblezici.
# -
# Input sentence: ['You', 'seem', 'happy.']
# Decoded sentence: semblezici.
# -
# Input sentence: ['You', 'seem', 'happy.']
# Decoded sentence: semblezici.
# -
# Input sentence: ['You', 'seem', 'happy.']
# Decoded sentence: semblezici.
# -
# Input sentence: ['You', 'seem', 'angry.']
# Decoded sentence: étionsici.!
# -
# Input sentence: ['You', 'screwed', 'up.']
# Decoded sentence: asperdu.!!!
# -
# Input sentence: ['You', 'screwed', 'up.']
# Decoded sentence: asperdu.!!!
# -
# Input sentence: ['You', 'owe', 'me', 'one.']
# Decoded sentence: meaiattendre.
# -
# Input sentence: ['You', 'owe', 'me', 'one.']
# Decoded sentence: meaiattendre.
# -
# Input sentence: ['You', 'need', 'to', 'go.']
# Decoded sentence: mefautyaller.
# -
# Input sentence: ['You', 'need', 'sleep.']
# Decoded sentence: besoindedela
# -
# Input sentence: ['You', 'need', 'sleep.']
# Decoded sentence: besoindedela
# -
# Input sentence: ['You', 'need', 'a', 'job.']
# Decoded sentence: besoind'und'un
# -
# Input sentence: ['You', 'need', 'a', 'job.']
# Decoded sentence: besoind'und'un
# -
# Input sentence: ['You', 'must', 'leave.']
# Decoded sentence: doisyaller.
# -
# Input sentence: ['You', 'must', 'do', 'it.']
# Decoded sentence: mefautysavoir.
# -
# Input sentence: ['You', 'must', 'do', 'it.']
# Decoded sentence: mefautysavoir.
# -
# Input sentence: ['You', 'look', 'upset.']
# Decoded sentence: avezl'airde
# -
# Input sentence: ['You', 'look', 'upset.']
# Decoded sentence: avezl'airde
# -
# Input sentence: ['You', 'look', 'upset.']
# Decoded sentence: avezl'airde
# -
# Input sentence: ['You', 'look', 'upset.']
# Decoded sentence: avezl'airde
# -
# Input sentence: ['You', 'look', 'tired.']
# Decoded sentence: avezl'airen
# -
# Input sentence: ['You', 'look', 'tired.']
# Decoded sentence: avezl'airen
# -
# Input sentence: ['You', 'look', 'tired.']
# Decoded sentence: avezl'airen
# -
# Input sentence: ['You', 'look', 'tired.']
# Decoded sentence: avezl'airen
# -
# Input sentence: ['You', 'look', 'smart.']
# Decoded sentence: avezl'airl'air
# -
# Input sentence: ['You', 'look', 'smart.']
# Decoded sentence: avezl'airl'air
# -
# Input sentence: ['You', 'look', 'smart.']
# ...
# Decoded sentence: gentil!elle
# -
# Input sentence: ['We', 'were', 'wasted.']
# Decoded sentence: nesommessauvés.
# -
# Input sentence: ['We', 'were', 'beaten.']
# Decoded sentence: étéétédéfaites.
# -
# Input sentence: ['We', 'want', 'change.']
# Decoded sentence: voulonstous.
# -
# Input sentence: ['We', 'volunteered.']
# Decoded sentence: nesommespas.
# -
# Input sentence: ['We', 'volunteered.']
# Decoded sentence: nesommespas.
# -
# Input sentence: ['We', 'volunteered.']
# Decoded sentence: nesommespas.
# -
# Input sentence: ['We', 'surrendered.']
# Decoded sentence: noussommespourquoi.
# -
# Input sentence: ['We', 'surrendered.']
# Decoded sentence: noussommespourquoi.
# -
# Input sentence: ['We', 'surrendered.']
# Decoded sentence: noussommespourquoi.
# -
# Input sentence: ['We', 'study', 'music.']
# Decoded sentence: leTom.lavous.
# -
# Input sentence: ['We', 'should', 'wait.']
# Decoded sentence: devrionsattendre.
# -
# Input sentence: ['We', 'should', 'help.']
# Decoded sentence: pouvonslire.
# -
# Input sentence: ['We', 'shook', 'hands.']
# Decoded sentence: nousavonsdes
# -
# Input sentence: ['We', 'saw', 'nothing.']
# Decoded sentence: neégal.jamais.
# -
# Input sentence: ['We', 'only', 'kissed.']
# Decoded sentence: nousavonsfini.
# -
# Input sentence: ['We', 'never', 'voted.']
# Decoded sentence: nepouvonspas.
# -
# Input sentence: ['We', 'needed', 'this.']
# Decoded sentence: abesoindevous.
# -
# Input sentence: ['We', 'needed', 'help.']
# Decoded sentence: nousbesoinde
# -
# Input sentence: ['We', 'need', 'to', 'win.']
# Decoded sentence: nousfautpartir.
# -
# Input sentence: ['We', 'need', 'to', 'win.']
# Decoded sentence: nousfautpartir.
# -
# Input sentence: ['We', 'need', 'to', 'eat.']
# Decoded sentence: nousfautyaller.
# -
# Input sentence: ['We', 'need', 'heroes.']
# Decoded sentence: nousbesoinde
# -
# Input sentence: ['We', 'need', 'action.']
# Decoded sentence: nousbesoinde
# -
# Input sentence: ['We', 'need', 'a', 'plan.']
# Decoded sentence: nousfautune
# -
# Input sentence: ['We', 'need', 'a', 'plan.']
# Decoded sentence: nousfautune
# -
# Input sentence: ['We', 'need', 'a', 'hero.']
# Decoded sentence: nousfautune
# -
# Input sentence: ['We', 'must', 'go', 'now.']
# Decoded sentence: nousfautyaller.
# -
# Input sentence: ['We', 'must', 'escape.']
# Decoded sentence: nousfautenaller.
# -
# Input sentence: ['We', 'must', 'decide.']
# Decoded sentence: nousfautque
# -
# Input sentence: ['We', 'must', 'attack.']
# Decoded sentence: nousfautpartir.
# -
# Input sentence: ['We', 'met', 'earlier.']
# Decoded sentence: noussommessauvés.
# -
# Input sentence: ['We', 'met', 'earlier.']
# Decoded sentence: noussommessauvés.
# -
# Input sentence: ['We', 'made', 'a', 'deal.']
# Decoded sentence: avonsununcerf-volant.
# -
# Input sentence: ['We', 'made', 'a', 'deal.']
# Decoded sentence: avonsununcerf-volant.
# -
# Input sentence: ['We', 'love', 'coffee.']
# Decoded sentence: adestomber.
# -
# Input sentence: ['We', 'laugh', 'a', 'lot.']
# Decoded sentence: avonspleuré.
# -
# Input sentence: ['We', 'know', 'enough.']
# Decoded sentence: aditdelavous.
# -
# Input sentence: ['We', 'knew', 'enough.']
# Decoded sentence: atous.àTom.
# -
# Input sentence: ['We', 'just', 'landed.']
# Decoded sentence: pourrionstous.
# -
# Input sentence: ['We', 'have', 'it', 'all.']
# Decoded sentence: avonsdesfini.
# -
# Input sentence: ['We', 'have', 'guests.']
# Decoded sentence: avonsbesoin
# -
# Input sentence: ['We', 'have', 'enough.']
# Decoded sentence: adesvin.!!!
# -
# Input sentence: ['We', 'have', 'a', 'pool.']
# Decoded sentence: avonsuneunvoiture.
# -
# Input sentence: ['We', 'have', 'a', 'plan.']
# Decoded sentence: disposed'un
# -
# Input sentence: ['We', 'have', 'a', 'deal.']
# Decoded sentence: disposeunelivre.
# -
# Input sentence: ['We', 'have', 'a', 'deal.']
# Decoded sentence: disposeunelivre.
# -
# Input sentence: ['We', 'have', 'a', 'deal.']
# Decoded sentence: disposeunelivre.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'to', 'stop.']
# Decoded sentence: nousnouspartir.
# -
# Input sentence: ['We', 'had', 'a', 'blast.']
# Decoded sentence: avonsununtaxi.
# -
# Input sentence: ['We', 'had', 'a', 'blast.']
# Decoded sentence: avonsununtaxi.
# -
# Input sentence: ['We', 'drank', 'a', 'lot.']
# Decoded sentence: voulonspleuré.
# -
# Input sentence: ['We', "didn't", 'kiss.']
# Decoded sentence: nesommespas
# -
# Input sentence: ['We', 'could', 'crash.']
# Decoded sentence: saitlire.nager.
# -
# Input sentence: ['We', "can't", 'do', 'it.']
# Decoded sentence: nepouvonspas
# -
# Input sentence: ['We', "can't", 'do', 'it.']
# Decoded sentence: nepouvonspas
# -
# Input sentence: ['We', 'can', 'proceed.']
# Decoded sentence: pouvonsnager.
# -
# Input sentence: ['We', 'can', 'do', 'that.']
# Decoded sentence: saitnager.y
# -
# Input sentence: ['We', 'are', 'doctors.']
# Decoded sentence: sommesriches.
# -
# Input sentence: ['We', 'are', 'all', 'set.']
# Decoded sentence: sommesdesavance.
# -
# Input sentence: ['We', 'are', 'all', 'set.']
# Decoded sentence: sommesdesavance.
# -
# Input sentence: ['We', 'almost', 'left.']
# Decoded sentence: nousfautensécurité.
# -
# Input sentence: ['We', 'all', 'laughed.']
# Decoded sentence: noustous.tous.
# -
# Input sentence: ['We', 'all', 'laughed.']
# Decoded sentence: noustous.tous.
# -
# Input sentence: ['We', 'all', 'laughed.']
# Decoded sentence: noustous.tous.
# -
# Input sentence: ['We', 'all', 'laughed.']
# Decoded sentence: noustous.tous.
# -
# Input sentence: ['We', 'all', 'know', 'it.']
# Decoded sentence: aenen!!!!domicile.
# -
# Input sentence: ['We', 'all', 'know', 'it.']
# Decoded sentence: aenen!!!!domicile.
# -
# Input sentence: ['We', 'all', 'knew', 'it.']
# Decoded sentence: atous.tous.
# -
# Input sentence: ['We', 'all', 'knew', 'it.']
# Decoded sentence: atous.tous.
# -
# Input sentence: ['We', 'all', 'do', 'that.']
# Decoded sentence: atous.partir.
# -
# Input sentence: ['We', 'all', 'cheered.']
# Decoded sentence: noustous.tous.
# -
# Input sentence: ['We', 'all', 'cheered.']
# Decoded sentence: noustous.tous.
# -
# Input sentence: ['Watch', 'yourself.']
# Decoded sentence: !!!!!!!!!!!
# -
# Input sentence: ['Watch', 'the', 'road.']
# Decoded sentence: lamain.!maintenant
# -
# Input sentence: ['Watch', 'the', 'road.']
# Decoded sentence: lamain.!maintenant
# -
# Input sentence: ['Watch', 'the', 'rear.']
# Decoded sentence: lamain.!maintenant
# -
# Input sentence: ['Watch', 'the', 'door.']
# Decoded sentence: laporte!neuf
# -
# Input sentence: ['Watch', 'the', 'door.']
# Decoded sentence: laporte!neuf
# -
# Input sentence: ['Wash', 'your', 'feet.']
# Decoded sentence: !jambes!!!!
# -
# Input sentence: ['Wash', 'your', 'feet.']
# Decoded sentence: !jambes!!!!
# -
# Input sentence: ['Wash', 'your', 'face.']
# Decoded sentence: !jambes!!cou
# -
# Input sentence: ['Was', 'that', 'a', 'yes?']
# Decoded sentence: unblague???
# -
# Input sentence: ['Walk', 'tall,', 'son.']
# Decoded sentence: tranquille!
# -
# Input sentence: ['Turn', 'on', 'the', 'TV.']
# Decoded sentence: !lit!!!!!!!
# -
# Input sentence: ['Turn', 'on', 'the', 'TV.']
# Decoded sentence: !lit!!!!!!!
# -
# Input sentence: ['Try', 'to', 'stop', 'me.']
# Decoded sentence: ça!lit!maintenant
# -
# Input sentence: ['Try', 'to', 'stop', 'me.']
# Decoded sentence: ça!lit!maintenant
# -
# Input sentence: ['Try', 'to', 'find', 'it.']
# Decoded sentence: àlamaison.!
# -
# Input sentence: ['Try', 'to', 'find', 'it.']
# Decoded sentence: àlamaison.!
# -
# Input sentence: ['Try', 'this', 'sauce.']
# Decoded sentence: deTom.dechaussure.
# -
# Input sentence: ['Try', 'not', 'to', 'cry.']
# Decoded sentence: n'estpas!!!
# -
# Input sentence: ['Try', 'not', 'to', 'cry.']
# Decoded sentence: n'estpas!!!
# -
# Input sentence: ['Tom,', "don't", 'die.']
# Decoded sentence: n'apaslà.d'accord.
# -
# Input sentence: ["Tom's", 'upstairs.']
# Decoded sentence: estentrainde
# -
# Input sentence: ["Tom's", 'sweating.']
# Decoded sentence: estgentille.
# -
# Input sentence: ["Tom's", 'not', 'here.']
# Decoded sentence: nepaspasici.
# -
# Input sentence: ["Tom's", 'innocent.']
# Decoded sentence: estdevenuen
# -
# Input sentence: ["Tom's", 'homeless.']
# Decoded sentence: estgentille.
# -
# Input sentence: ["Tom's", 'harmless.']
# Decoded sentence: estgentille.
# -
# Input sentence: ["Tom's", 'drowning.']
# Decoded sentence: estentrainde
# -
# Input sentence: ["Tom's", 'drowning.']
# Decoded sentence: estentrainde
# -
# Input sentence: ["Tom's", 'dreaming.']
# Decoded sentence: estentrainde
# -
# Input sentence: ["Tom's", 'diabetic.']
# Decoded sentence: estconnu.avance.
# -
# Input sentence: ["Tom's", 'confused.']
# Decoded sentence: aétéparalysé.
# -
# Input sentence: ["Tom's", 'a', 'doctor.']
# Decoded sentence: estunmenteur.
# -
# Input sentence: ["Tom's", 'a', 'doctor.']
# Decoded sentence: estunmenteur.
# -
# Input sentence: ['Tom', "won't", 'mind.']
# Decoded sentence: nesaitpas.pas.
# -
# Input sentence: ['Tom', "won't", 'know.']
# Decoded sentence: nesaitpas.nager.
# -
# Input sentence: ['Tom', "won't", 'know.']
# Decoded sentence: nesaitpas.nager.
# -
# Input sentence: ['Tom', 'will', 'check.']
# Decoded sentence: marchevite.
# -
# Input sentence: ['Tom', 'was', 'thirty.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ['Tom', 'was', 'stoned.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ['Tom', 'was', 'stoned.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ['Tom', 'was', 'stoned.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ['Tom', 'was', 'lonely.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ['Tom', 'was', 'dumped.']
# Decoded sentence: étaitétécruel.
# -
# Input sentence: ['Tom', 'was', 'better.']
# Decoded sentence: étaitdur.espoir.
# -
# Input sentence: ['Tom', 'warned', 'you.']
# Decoded sentence: aditdevous.
# -
# Input sentence: ['Tom', 'trusts', 'you.']
# Decoded sentence: abesoindevous.
# -
# Input sentence: ['Tom', 'trusts', 'you.']
# Decoded sentence: abesoindevous.
# -
# Input sentence: ['Tom', 'trusts', 'him.']
# Decoded sentence: lemondeleprocès.
# -
# Input sentence: ['Tom', 'stopped', 'it.']
# Decoded sentence: letrouvé.le
# -
# Input sentence: ['Tom', 'stopped', 'it.']
# Decoded sentence: letrouvé.le
# -
# Input sentence: ['Tom', 'stopped', 'it.']
# Decoded sentence: letrouvé.le
# -
# Input sentence: ['Tom', 'set', 'a', 'trap.']
# Decoded sentence: aununtrente.
# -
# Input sentence: ['Tom', 'seems', 'nice.']
# Decoded sentence: al'airl'air
# -
# Input sentence: ['Tom', 'seems', 'nice.']
# Decoded sentence: al'airl'air
# -
# Input sentence: ['Tom', 'seems', 'lost.']
# Decoded sentence: al'airl'air
# -
# Input sentence: ['Tom', 'seems', 'lost.']
# Decoded sentence: al'airl'air
# -
# Input sentence: ['Tom', 'seems', 'calm.']
# Decoded sentence: al'airentrain
# -
# Input sentence: ['Tom', 'seems', 'calm.']
# Decoded sentence: al'airentrain
# -
# Input sentence: ['Tom', 'passed', 'out.']
# Decoded sentence: esthuitheures
# -
# Input sentence: ['Tom', 'needs', 'work.']
# Decoded sentence: abesoindetoi.
# -
# Input sentence: ['Tom', 'needs', 'this.']
# Decoded sentence: abesoindela
# -
# Input sentence: ['Tom', 'needs', 'help.']
# Decoded sentence: abesoindevous.
# -
# Input sentence: ['Tom', 'may', 'change.']
# Decoded sentence: chienspourrait
# -
# Input sentence: ['Tom', 'made', 'plans.']
# Decoded sentence: adesdesdessus.
# -
# Input sentence: ['Tom', 'loves', 'maps.']
# Decoded sentence: afaitlefaire.
# -
# Input sentence: ['Tom', 'loves', 'dogs.']
# Decoded sentence: afaitlefaire.
# -
# Input sentence: ['Tom', 'loves', 'Mary.']
# Decoded sentence: aapprécié.ça.
# -
# Input sentence: ['Tom', 'loves', 'Mary.']
# Decoded sentence: aapprécié.ça.
# -
# Input sentence: ['Tom', 'looks', 'sick.']
# Decoded sentence: al'airentrain
# -
# Input sentence: ['Tom', 'likes', 'tofu.']
# Decoded sentence: seraibien.Tom.
# -
# Input sentence: ['Tom', 'likes', 'them.']
# Decoded sentence: lesbesoin.de
# -
# Input sentence: ['Tom', 'likes', 'them.']
# Decoded sentence: lesbesoin.de
# -
# Input sentence: ['Tom', 'likes', 'snow.']
# Decoded sentence: seraibien.bien.
# -
# Input sentence: ['Tom', 'likes', 'rock.']
# Decoded sentence: l'aimebien.
# -
# Input sentence: ['Tom', 'liked', 'that.']
# Decoded sentence: aapprécié.ça.
# -
# Input sentence: ['Tom', 'knows', 'that.']
# Decoded sentence: afaitlefaire.
# -
# Input sentence: ['Tom', 'knows', 'that.']
# Decoded sentence: afaitlefaire.
# -
# Input sentence: ['Tom', 'knows', 'Mary.']
# Decoded sentence: afaitdeslachance.
# -
# Input sentence: ['Tom', "isn't", 'safe.']
# Decoded sentence: nesommesvieux.
# -
# Input sentence: ['Tom', "isn't", 'safe.']
# Decoded sentence: nesommesvieux.
# -
# Input sentence: ['Tom', "isn't", 'rude.']
# Decoded sentence: nesaitpasmal.
# -
# Input sentence: ['Tom', "isn't", 'rich.']
# Decoded sentence: nesommespas
# -
# Input sentence: ['Tom', "isn't", 'here.']
# Decoded sentence: nepasici.ici.
# -
# Input sentence: ['Tom', "isn't", 'dumb.']
# Decoded sentence: nesuispasen
# -
# Input sentence: ['Tom', 'is', 'working.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'thirsty.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'talking.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'staying.']
# Decoded sentence: vaestTom.Tom.
# -
# Input sentence: ['Tom', 'is', 'starved.']
# Decoded sentence: estl'airtriste.
# -
# Input sentence: ['Tom', 'is', 'starved.']
# Decoded sentence: estl'airtriste.
# -
# Input sentence: ['Tom', 'is', 'special.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'smashed.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'sincere.']
# Decoded sentence: estdevenumalade.
# -
# Input sentence: ['Tom', 'is', 'playing.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'packing.']
# Decoded sentence: adulachance.
# -
# Input sentence: ['Tom', 'is', 'packing.']
# Decoded sentence: adulachance.
# -
# Input sentence: ['Tom', 'is', 'outside.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'on', 'duty.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'my', 'boss.']
# Decoded sentence: faitmonchien.
# -
# Input sentence: ['Tom', 'is', 'married.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'leaving.']
# Decoded sentence: vieestestet
# -
# Input sentence: ['Tom', 'is', 'kidding.']
# Decoded sentence: tempsestest
# -
# Input sentence: ['Tom', 'is', 'kidding.']
# Decoded sentence: tempsestest
# -
# Input sentence: ['Tom', 'is', 'helpful.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'driving.']
# Decoded sentence: estentrainde
# -
# Input sentence: ['Tom', 'is', 'awesome.']
# Decoded sentence: estestestet
# -
# Input sentence: ['Tom', 'is', 'at', 'work.']
# Decoded sentence: estdutrainde
# -
# Input sentence: ['Tom', 'is', 'a', 'pilot.']
# Decoded sentence: estunlivre.
# -
# Input sentence: ['Tom', 'is', 'a', 'moron.']
# Decoded sentence: estunlivre.
# -
# Input sentence: ['Tom', 'is', 'a', 'guest.']
# Decoded sentence: estunlivre.
# -
# Input sentence: ['Tom', 'is', 'a', 'felon.']
# Decoded sentence: estunlivre.
# -
# Input sentence: ['Tom', 'is', 'a', 'crook.']
# Decoded sentence: estunlivre.
# -
# Input sentence: ['Tom', 'hates', 'dogs.']
# Decoded sentence: mesenslefaire.
# -
# Input sentence: ['Tom', 'hates', 'dogs.']
# Decoded sentence: mesenslefaire.
# -
# Input sentence: ['Tom', 'hates', 'Mary.']
# Decoded sentence: lecrois.ça.
# -
# Input sentence: ['Tom', 'hated', 'that.']
# Decoded sentence: cela.cela.ça.
# -
# Input sentence: ['Tom', 'had', 'to', 'run.']
# Decoded sentence: nousfaitpartir.
# -
# Input sentence: ['Tom', 'got', 'dumped.']
# Decoded sentence: étaitétéparalysé.
# -
# Input sentence: ['Tom', 'fired', 'Mary.']
# Decoded sentence: al'airdelachance.
# -
# Input sentence: ['Tom', 'fired', 'Mary.']
# Decoded sentence: al'airdelachance.
# -
# Input sentence: ['Tom', 'felt', 'great.']
# Decoded sentence: mefautfaitmal.
# -
# Input sentence: ['Tom', 'draws', 'well.']
# Decoded sentence: abien.àlasanté.
# -
# Input sentence: ['Tom', 'drank', 'milk.']
# Decoded sentence: afaitTom.Tom.
# -
# Input sentence: ['Tom', 'died', 'at', '65.']
# Decoded sentence: adulamaison.
# -
# Input sentence: ['Tom', 'did', 'it', 'all.']
# Decoded sentence: aétéenlachance.
# -
# Input sentence: ['Tom', "can't", 'swim.']
# Decoded sentence: nesaitpasnager.
# -
# Input sentence: ['Tom', "can't", 'help.']
# Decoded sentence: nesaitpasnager.
